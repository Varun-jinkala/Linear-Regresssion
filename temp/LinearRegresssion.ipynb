# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("C:\\Users\\varun\\Downloads\\archive (2).zip")
df.head()
# Out:
#    Hours_Studied  Marks
# 0           4.76  46.27
# 1           3.00  34.30
# 2           2.08  33.63
# 3           4.04  47.81
# 4           9.49  66.26

# %%
X = df[['Hours_Studied']] 
y = df['Marks']

# %%
plt.scatter(X, y,color='brown')
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): 5.227857868906978
# Intercept (c): 18.25366773939543

# %%
pred = model.predict([[9]])
print("Predicted marks:", pred[0])
# Out:
# Predicted marks: 65.30438855955823
# C:\Users\varun\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, y,color='black')
plt.plot(X, model.predict(X), color='brown')
plt.show()
